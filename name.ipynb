# %%
import os
import sys

folder_name = "exps/debug/882999/particles/Pred"
file_names = os.listdir(folder_name)
for name in file_names:
    old_name = folder_name + '/' + name
    new_name = folder_name + '/' + '8' + name
    os.rename(old_name, new_name)
    print(new_name)

# %%
import os
import sys

folder_name = "exps/debug/882999/particles/GT"
file_names = os.listdir(folder_name)
for name in file_names:
    old_name = folder_name + '/' + name
    new_name = folder_name + '/' + '8' + name
    os.rename(old_name, new_name)
    print(new_name)

# %%
import numpy as np
a = np.load('0000.npz')
a.files
# Out:
# ['pos', 'vel']

# %%
pos=a['pos']
pos.shape
# Out:
# (11532, 3)

# %%
import matplotlib
matplotlib.use('Agg')
from matplotlib import pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure()
ax = Axes3D(fig)
ax.scatter(pos[:,0], pos[:,1], pos[:,2], s=1, c='r', marker='.')
ax.set_xlim(-2,2)
ax.set_ylim(-2,2)
ax.legend()
plt.show()
# Out:
# /home/rayne/anaconda3/envs/py3.7/lib/python3.7/site-packages/ipykernel_launcher.py:4: MatplotlibDeprecationWarning: Axes3D(fig) adding itself to the figure is deprecated since 3.4. Pass the keyword argument auto_add_to_figure=False and use fig.add_axes(ax) to suppress this warning. The default value of auto_add_to_figure will change to False in mpl3.5 and True values will no longer work in 3.6.  This is consistent with other Axes classes.
#   after removing the cwd from sys.path.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
import os.path as osp
from utils.particles_utils import record2obj
particle_name = 'gtgt.obj'
with open(particle_name, 'w') as fp:
    record2obj(pos, fp, color=[255, 0, 0]) # red
