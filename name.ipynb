# %%
import os
import sys

folder_name = "exps/debug/882999/particles/Pred"
file_names = os.listdir(folder_name)
for name in file_names:
    old_name = folder_name + '/' + name
    new_name = folder_name + '/' + '8' + name
    os.rename(old_name, new_name)
    print(new_name)
# Out:
# exps/debug/882999/particles/Pred/8pred42.obj
# exps/debug/882999/particles/Pred/8pred48.obj
# exps/debug/882999/particles/Pred/8pred22.obj
# exps/debug/882999/particles/Pred/8pred13.obj
# exps/debug/882999/particles/Pred/8pred27.obj
# exps/debug/882999/particles/Pred/8pred8.obj
# exps/debug/882999/particles/Pred/8pred55.obj
# exps/debug/882999/particles/Pred/8pred59.obj
# exps/debug/882999/particles/Pred/8pred14.obj
# exps/debug/882999/particles/Pred/8pred46.obj
# exps/debug/882999/particles/Pred/8pred54.obj
# exps/debug/882999/particles/Pred/8pred4.obj
# exps/debug/882999/particles/Pred/8pred2.obj
# exps/debug/882999/particles/Pred/8pred18.obj
# exps/debug/882999/particles/Pred/8pred24.obj
# exps/debug/882999/particles/Pred/8pred10.obj
# exps/debug/882999/particles/Pred/8pred57.obj
# exps/debug/882999/particles/Pred/8pred12.obj
# exps/debug/882999/particles/Pred/8pred35.obj
# exps/debug/882999/particles/Pred/8pred34.obj
# exps/debug/882999/particles/Pred/8pred37.obj
# exps/debug/882999/particles/Pred/8pred28.obj
# exps/debug/882999/particles/Pred/8pred15.obj
# exps/debug/882999/particles/Pred/8pred31.obj
# exps/debug/882999/particles/Pred/8pred19.obj
# exps/debug/882999/particles/Pred/8pred23.obj
# exps/debug/882999/particles/Pred/8pred38.obj
# exps/debug/882999/particles/Pred/8pred11.obj
# exps/debug/882999/particles/Pred/8pred26.obj
# exps/debug/882999/particles/Pred/8pred1.obj
# exps/debug/882999/particles/Pred/8pred16.obj
# exps/debug/882999/particles/Pred/8pred36.obj
# exps/debug/882999/particles/Pred/8pred39.obj
# exps/debug/882999/particles/Pred/8pred47.obj
# exps/debug/882999/particles/Pred/8pred52.obj
# exps/debug/882999/particles/Pred/8pred41.obj
# exps/debug/882999/particles/Pred/8pred17.obj
# exps/debug/882999/particles/Pred/8pred9.obj
# exps/debug/882999/particles/Pred/8pred29.obj
# exps/debug/882999/particles/Pred/8pred21.obj
# exps/debug/882999/particles/Pred/8pred43.obj
# exps/debug/882999/particles/Pred/8pred58.obj
# exps/debug/882999/particles/Pred/8pred20.obj
# exps/debug/882999/particles/Pred/8pred3.obj
# exps/debug/882999/particles/Pred/8pred7.obj
# exps/debug/882999/particles/Pred/8pred6.obj
# exps/debug/882999/particles/Pred/8pred56.obj
# exps/debug/882999/particles/Pred/8pred51.obj
# exps/debug/882999/particles/Pred/8pred32.obj
# exps/debug/882999/particles/Pred/8pred45.obj
# exps/debug/882999/particles/Pred/8pred5.obj
# exps/debug/882999/particles/Pred/8pred50.obj
# exps/debug/882999/particles/Pred/8pred30.obj
# exps/debug/882999/particles/Pred/8pred53.obj
# exps/debug/882999/particles/Pred/8pred40.obj
# exps/debug/882999/particles/Pred/8pred33.obj
# exps/debug/882999/particles/Pred/8pred25.obj
# exps/debug/882999/particles/Pred/8pred49.obj
# exps/debug/882999/particles/Pred/8pred44.obj

# %%
import os
import sys

folder_name = "exps/debug/882999/particles/GT"
file_names = os.listdir(folder_name)
for name in file_names:
    old_name = folder_name + '/' + name
    new_name = folder_name + '/' + '8' + name
    os.rename(old_name, new_name)
    print(new_name)
# Out:
# exps/debug/882999/particles/GT/8gt13.obj
# exps/debug/882999/particles/GT/8gt28.obj
# exps/debug/882999/particles/GT/8gt38.obj
# exps/debug/882999/particles/GT/8gt56.obj
# exps/debug/882999/particles/GT/8gt16.obj
# exps/debug/882999/particles/GT/8gt15.obj
# exps/debug/882999/particles/GT/8gt19.obj
# exps/debug/882999/particles/GT/8gt8.obj
# exps/debug/882999/particles/GT/8gt39.obj
# exps/debug/882999/particles/GT/8gt46.obj
# exps/debug/882999/particles/GT/8gt22.obj
# exps/debug/882999/particles/GT/8gt57.obj
# exps/debug/882999/particles/GT/8gt40.obj
# exps/debug/882999/particles/GT/8gt34.obj
# exps/debug/882999/particles/GT/8gt52.obj
# exps/debug/882999/particles/GT/8gt58.obj
# exps/debug/882999/particles/GT/8gt49.obj
# exps/debug/882999/particles/GT/8gt41.obj
# exps/debug/882999/particles/GT/8gt26.obj
# exps/debug/882999/particles/GT/8gt50.obj
# exps/debug/882999/particles/GT/8gt53.obj
# exps/debug/882999/particles/GT/8gt12.obj
# exps/debug/882999/particles/GT/8gt10.obj
# exps/debug/882999/particles/GT/8gt35.obj
# exps/debug/882999/particles/GT/8gt51.obj
# exps/debug/882999/particles/GT/8gt59.obj
# exps/debug/882999/particles/GT/8gt42.obj
# exps/debug/882999/particles/GT/8gt47.obj
# exps/debug/882999/particles/GT/8gt36.obj
# exps/debug/882999/particles/GT/8gt3.obj
# exps/debug/882999/particles/GT/8gt11.obj
# exps/debug/882999/particles/GT/8gt14.obj
# exps/debug/882999/particles/GT/8gt21.obj
# exps/debug/882999/particles/GT/8gt17.obj
# exps/debug/882999/particles/GT/8gt20.obj
# exps/debug/882999/particles/GT/8gt54.obj
# exps/debug/882999/particles/GT/8gt55.obj
# exps/debug/882999/particles/GT/8gt32.obj
# exps/debug/882999/particles/GT/8gt30.obj
# exps/debug/882999/particles/GT/8gt44.obj
# exps/debug/882999/particles/GT/8gt5.obj
# exps/debug/882999/particles/GT/8gt23.obj
# exps/debug/882999/particles/GT/8gt2.obj
# exps/debug/882999/particles/GT/8gt24.obj
# exps/debug/882999/particles/GT/8gt9.obj
# exps/debug/882999/particles/GT/8gt37.obj
# exps/debug/882999/particles/GT/8gt6.obj
# exps/debug/882999/particles/GT/8gt7.obj
# exps/debug/882999/particles/GT/8gt25.obj
# exps/debug/882999/particles/GT/8gt27.obj
# exps/debug/882999/particles/GT/8gt31.obj
# exps/debug/882999/particles/GT/8gt43.obj
# exps/debug/882999/particles/GT/8gt33.obj
# exps/debug/882999/particles/GT/8gt45.obj
# exps/debug/882999/particles/GT/8gt4.obj
# exps/debug/882999/particles/GT/8gt48.obj
# exps/debug/882999/particles/GT/8gt29.obj
# exps/debug/882999/particles/GT/8gt18.obj
# exps/debug/882999/particles/GT/8gt1.obj
